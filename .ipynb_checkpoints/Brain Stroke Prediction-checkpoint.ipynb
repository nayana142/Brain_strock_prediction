# %% [markdown]
# # <div style="text-align: center; background-color:pink; font-family:Georgia, serif; color: black; padding: 20px;line-height: 1;border-radius:5px; border: 2px solid black;">Brain Stroke Prediction</div>

# %% [markdown]
# # Stroke
# * A stroke, or brain attack, happens when blood flow to your brain is stopped.The brain needs a constant supply of oxygen and nutrients in order to work well. If blood supply is stopped even for a short time, this can cause problems. Brain cells begin to die after just a few minutes without blood or oxygen.
# * Signs and symptoms of a stroke may include an inability to move or feel on one side of the body, problems understanding or speaking, dizziness, or loss of vision to one side. Signs and symptoms often appear soon after the stroke has occurred. If symptoms last less than one or two hours, the stroke is a transient ischemic attack (TIA), also called a mini-stroke.
#
# * Here are 2 kinds of stroke: ischemic and hemorrhagic.
#
#    * Ischemic stroke. This is the most common type of stroke. It happens when a major blood vessel in the brain is blocked. It may be blocked by a blood clot. Or it may be blocked by a buildup of fatty deposit and cholesterol. This buildup is called plaque.
#
#    * Hemorrhagic stroke. This occurs when a blood vessel in your brain bursts, spilling blood into nearby tissues. With a hemorrhagic stroke, pressure builds up in the nearby brain tissue. This causes even more damage and irritation.
#
# ### Risk factors for strok
# * The main risk factor for stroke is high blood pressure.
# * Other risk factors include high blood cholesterol, tobacco smoking, obesity, diabetes mellitus, a previous TIA(mini-strokes), end-stage kidney disease, and atrial fibrillation.
# * An ischemic stroke is typically caused by blockage of a blood vessel, though there are also less common causes.
# * A hemorrhagic stroke is caused by either bleeding directly into the brain or into the space between the brain's membranes. Bleeding may occur due to a ruptured brain aneurysm.
#
# ### How can we diagnose
# * Diagnosis is typically based on a physical exam and is supported by medical imaging such as a CT scan or MRI scan.
# * A CT scan can rule out bleeding, but may not necessarily rule out ischemia, which early on typically does not show up on a CT scan.
# * Other tests such as an electrocardiogram (ECG) and blood tests are done to determine risk factors and rule out other possible causes. Low blood sugar may cause similar symptoms.

# %% [markdown]
# ### Attribute Information
#
# 1) gender: "Male", "Female" or "Other"
#
# 2) age: age of the patient
#
# 3) hypertension: 0 if the patient doesn't have hypertension, 1 if the patient has hypertension (high blood pressure)
#
# 4) heart disease: 0 if the patient doesn't have any heart diseases, 1 if the patient has a heart disease
#
# 5) Ever-married: "No" or "Yes"
#
# 6) work type: "children", "Govtjov"-Government job, "Never worked", "Private" or "Self-employed"
#
# 7) Residencetype: "Rural" or "Urban"
#
# 8) avg glucose level: average glucose level in blood
#
# 9) BMI: body mass index
#
# 10) smoking_status: "formerly smoked"-used to be , "never smoked", "smokes" or "Unknown"*
#
# 11) stroke: 1 if the patient had a stroke or 0 if not

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.metrics import classification_report,accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from imblearn.over_sampling import SMOTE
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import Data

# %%
data=pd.read_csv('brain_stroke.csv')

# %%
data
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %% [markdown]
# # Data Exploratory Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
data.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4981.000000   4981.000000    4981.000000        4981.000000
# mean     43.419859      0.096165       0.055210         105.943562
# std      22.662755      0.294848       0.228412          45.075373
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.230000
# 50%      45.000000      0.000000       0.000000          91.850000
# 75%      61.000000      0.000000       0.000000         113.860000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4981.000000  4981.000000
# mean     28.498173     0.049789
# std       6.790464     0.217531
# min      14.000000     0.000000
# 25%      23.700000     0.000000
# 50%      28.100000     0.000000
# 75%      32.600000     0.000000
# max      48.900000     1.000000

# %%
data.describe(include='all').T
# Out:
#                     count unique           top  freq        mean        std  \
# gender               4981      2        Female  2907         NaN        NaN
# age                4981.0    NaN           NaN   NaN   43.419859  22.662755
# hypertension       4981.0    NaN           NaN   NaN    0.096165   0.294848
# heart_disease      4981.0    NaN           NaN   NaN     0.05521   0.228412
# ever_married         4981      2           Yes  3280         NaN        NaN
# work_type            4981      4       Private  2860         NaN        NaN
# Residence_type       4981      2         Urban  2532         NaN        NaN
# avg_glucose_level  4981.0    NaN           NaN   NaN  105.943562  45.075373
# bmi                4981.0    NaN           NaN   NaN   28.498173   6.790464
# smoking_status       4981      4  never smoked  1838         NaN        NaN
# stroke             4981.0    NaN           NaN   NaN    0.049789   0.217531
#
#                      min    25%    50%     75%     max
# ...

# %%
# unique values in columns
for i in data.columns:
    print(i,':',data[i].nunique())
# Out:
# gender : 2
# age : 104
# hypertension : 2
# heart_disease : 2
# ever_married : 2
# work_type : 4
# Residence_type : 2
# avg_glucose_level : 3895
# bmi : 342
# smoking_status : 4
# stroke : 2

# %%
data.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# * Cleaned data

# %%
data['age']=data['age'].astype(int)

# %%
data
# Out:
#       gender  age  hypertension  heart_disease ever_married      work_type  \
# 0       Male   67             0              1          Yes        Private
# 1       Male   80             0              1          Yes        Private
# 2     Female   49             0              0          Yes        Private
# 3     Female   79             1              0          Yes  Self-employed
# 4       Male   81             0              0          Yes        Private
# ...      ...  ...           ...            ...          ...            ...
# 4976    Male   41             0              0           No        Private
# 4977    Male   40             0              0          Yes        Private
# 4978  Female   45             1              0          Yes       Govt_job
# 4979    Male   40             0              0          Yes        Private
# 4980  Female   80             1              0          Yes        Private
#
# ...

# %%
data.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4981.000000   4981.000000    4981.000000        4981.000000
# mean     43.408552      0.096165       0.055210         105.943562
# std      22.683945      0.294848       0.228412          45.075373
# min       0.000000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.230000
# 50%      45.000000      0.000000       0.000000          91.850000
# 75%      61.000000      0.000000       0.000000         113.860000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4981.000000  4981.000000
# mean     28.498173     0.049789
# std       6.790464     0.217531
# min      14.000000     0.000000
# 25%      23.700000     0.000000
# 50%      28.100000     0.000000
# 75%      32.600000     0.000000
# max      48.900000     1.000000

# %%
data[data['age']==0]
# Out:
#       gender  age  hypertension  heart_disease ever_married work_type  \
# 314   Female    0             0              0           No  children
# 327   Female    0             0              0           No  children
# 504   Female    0             0              0           No  children
# 895     Male    0             0              0           No  children
# 909     Male    0             0              0           No  children
# 1003  Female    0             0              0           No  children
# 1111  Female    0             0              0           No  children
# 1212    Male    0             0              0           No  children
# 1474    Male    0             0              0           No  children
# 1487  Female    0             0              0           No  children
# 1663  Female    0             0              0           No  children
# 1821    Male    0             0              0           No  children
# ...

# %% [markdown]
# # Data Visualization

# %%
plt.title('Gender distribution')
sns.countplot(data,x='gender')
plt.xlabel('Gender')
plt.show()

# %%
data['ever_married'].value_counts().plot(kind='pie',explode=(0,0.1),shadow=True,autopct='%1.2f%%')
plt.title('Marital Status Distribution')
plt.show()

# %%
plt.figure(figsize=(15,8))
data['age'].value_counts().plot(kind='bar')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.show()

# %%
sns.countplot(data,x='hypertension')
plt.title('Hypertension Distribution')
plt.xlabel('Hypertension')
plt.show()

# %%
sns.countplot(data,x='work_type')
plt.title('Work_type Overview')
plt.xlabel('Work_type')
plt.show()

# %%
data['Residence_type'].value_counts().plot(kind='pie',autopct='%1.2f%%',shadow=True,explode=(0,0.1))
plt.title('Residence_type Distribution')
plt.show()

# %%
sns.histplot(data,x=data['avg_glucose_level'],kde=True)
plt.title('Avg_glucose_level')
plt.show()

# %%
sns.histplot(data,x=data['bmi'],kde=True)
plt.title('Body Mass Index')
plt.show()

# %%
sns.countplot(data,x=data['smoking_status'])
plt.title('Smoking_status')
plt.show()

# %%
data['stroke'].value_counts().plot(kind='pie',explode=(0,0.1),shadow=True,autopct='%1.2f%%')
plt.title('Stroke Distribution')
plt.show()

# %%
sns.barplot(data,x='work_type',y='hypertension')
plt.title('Hypertension Prevalence by Work Type')
plt.xlabel('Work Type')
plt.ylabel('Proportion of Hypertension')
plt.show()

# %%
sns.barplot(data,x='work_type',y='heart_disease')
plt.title('Heart Disease Prevalence by Work Type')
plt.xlabel('Work Type')
plt.ylabel('Proportion of Heart Disease')
plt.show()

# %%
sns.barplot(data,x='Residence_type',y='heart_disease',hue='smoking_status')
plt.title('Heart Disease Prevalence by Residence Type and Smoking Status')
plt.xlabel('Residence Type')
plt.ylabel('Proportion of Heart Disease') 
plt.show()

# %%
for i in data.columns:
    if pd.api.types.is_numeric_dtype(data[i]):
        plt.figure(figsize=(8, 6))
        sns.boxplot(x=data[i])
        plt.title(f'{i} Distribution')
        plt.show()

# %%
q1=np.percentile(data['avg_glucose_level'],25)
q1
# Out:
# np.float64(77.23)

# %%
q3=np.percentile(data['avg_glucose_level'],75)
q3
# Out:
# np.float64(113.86)

# %%
iqr=q3-q1
iqr
# Out:
# np.float64(36.629999999999995)

# %%
lb=q1-iqr*1.5
lb
# Out:
# np.float64(22.28500000000001)

# %%
ub=q3+iqr*1.5
ub
# Out:
# np.float64(168.805)

# %%
df=data[(data['avg_glucose_level']>lb ) & (data['avg_glucose_level']<ub)]
df
# Out:
#       gender  age  hypertension  heart_disease ever_married work_type  \
# 1       Male   80             0              1          Yes   Private
# 5       Male   74             1              1          Yes   Private
# 6     Female   69             0              0           No   Private
# 7     Female   78             0              0          Yes   Private
# 8     Female   81             1              0          Yes   Private
# ...      ...  ...           ...            ...          ...       ...
# 4974    Male   58             0              0          Yes  Govt_job
# 4976    Male   41             0              0           No   Private
# 4978  Female   45             1              0          Yes  Govt_job
# 4979    Male   40             0              0          Yes   Private
# 4980  Female   80             1              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# ...

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['avg_glucose_level'])
plt.title('Avg_glucose_level Distribution')
plt.show()

# %%
sns.barplot(data,x='smoking_status',y='avg_glucose_level',hue='heart_disease')
plt.title('Average Glucose Level by Smoking Status and Heart Disease')
plt.xlabel('Smoking Status')
plt.ylabel('Average Glucose Level')
plt.show()

# %%
sns.barplot(data,x='gender',y='bmi',hue='heart_disease')
plt.title('Average BMI by Gender and Heart Disease Status')
plt.xlabel('Gender')
plt.ylabel('Average BMI')
plt.show()

# %%
# pip install statsmodels

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='age', y='stroke', logistic=True, ci=None)
plt.title('Probability of Stroke by Age')
plt.xlabel('Age')
plt.ylabel('Probability of Stroke')
plt.show()

# %%
bins = [0, 30, 40, 50, 60, 70, 80, 100]
labels = ['0-30', '31-40', '41-50', '51-60', '61-70', '71-80', '81-100']
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

# %%
# age_bin_strokes = df[df['stroke'] == 1].groupby('age_group')['stroke'].count().reset_index()
# age_bin_strokes

# %%
# Calculate stroke proportions for each age bin
age_bin_proportions = df.groupby('age_group')['stroke'].count().reset_index()
age_bin_proportions
# Out:
#   age_group  stroke
# 0      0-30    1430
# 1     31-40     604
# 2     41-50     652
# 3     51-60     671
# 4     61-70     473
# 5     71-80     410
# 6    81-100     139

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=age_bin_proportions, x='age_group', y='stroke')

# Add title and labels
plt.title('Probability of Stroke by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Proportion of Stroke')

# Display the plot
plt.show()

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke', 'age_group'],
#       dtype='object')

# %%
df=df.drop(columns=['age_group'],axis=1)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#       gender  age  hypertension  heart_disease ever_married work_type  \
# 0       Male   80             0              1          Yes   Private
# 1       Male   74             1              1          Yes   Private
# 2     Female   69             0              0           No   Private
# 3     Female   78             0              0          Yes   Private
# 4     Female   81             1              0          Yes   Private
# ...      ...  ...           ...            ...          ...       ...
# 4374    Male   58             0              0          Yes  Govt_job
# 4375    Male   41             0              0           No   Private
# 4376  Female   45             1              0          Yes  Govt_job
# 4377    Male   40             0              0          Yes   Private
# 4378  Female   80             1              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# ...

# %% [markdown]
# # Data Preprocessing

# %%
x=df.iloc[:,0:10]
x
# Out:
#       gender  age  hypertension  heart_disease ever_married work_type  \
# 0       Male   80             0              1          Yes   Private
# 1       Male   74             1              1          Yes   Private
# 2     Female   69             0              0           No   Private
# 3     Female   78             0              0          Yes   Private
# 4     Female   81             1              0          Yes   Private
# ...      ...  ...           ...            ...          ...       ...
# 4374    Male   58             0              0          Yes  Govt_job
# 4375    Male   41             0              0           No   Private
# 4376  Female   45             1              0          Yes  Govt_job
# 4377    Male   40             0              0          Yes   Private
# 4378  Female   80             1              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status
# 0             Rural             105.92  32.5     never smoked
# ...

# %%
# y=df.pop('stroke')
y=df['stroke']

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4374    0
# 4375    0
# 4376    0
# 4377    0
# 4378    0
# Name: stroke, Length: 4379, dtype: int64

# %%
categorical_features=df.select_dtypes(include='object').columns
categorical_features
# Out:
# Index(['gender', 'ever_married', 'work_type', 'Residence_type',
#        'smoking_status'],
#       dtype='object')

# %%
numerical_feature=df.select_dtypes(include=['int','float']).columns
numerical_feature
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi',
#        'stroke'],
#       dtype='object')

# %%
le=LabelEncoder()

# %%
for i in categorical_features:
    x[i]=le.fit_transform(x[i])

# %%
x
# Out:
#       gender  age  hypertension  heart_disease  ever_married  work_type  \
# 0          1   80             0              1             1          1
# 1          1   74             1              1             1          1
# 2          0   69             0              0             0          1
# 3          0   78             0              0             1          1
# 4          0   81             1              0             1          1
# ...      ...  ...           ...            ...           ...        ...
# 4374       1   58             0              0             1          0
# 4375       1   41             0              0             0          1
# 4376       0   45             1              0             1          0
# 4377       1   40             0              0             1          1
# 4378       0   80             1              0             1          1
#
#       Residence_type  avg_glucose_level   bmi  smoking_status
# ...

# %%
sns.histplot(data=x.corr())
plt.title('Data Correlation')
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#       gender  age  hypertension  heart_disease  ever_married  work_type  \
# 2519       0   63             0              0             1          1
# 1767       0   60             0              0             1          0
# 1056       1   63             0              0             1          1
# 2860       0   37             0              0             1          1
# 2957       1   30             0              0             1          1
# ...      ...  ...           ...            ...           ...        ...
# 3444       1   33             0              0             1          1
# 466        0   56             0              0             1          1
# 3092       0   38             0              0             1          0
# 3772       0   43             0              0             1          1
# 860        1   47             0              0             1          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status
# ...

# %%
x_test
# Out:
#       gender  age  hypertension  heart_disease  ever_married  work_type  \
# 175        1   58             1              0             1          0
# 3659       0   13             0              0             0          3
# 3702       0   27             0              0             0          1
# 2702       0    2             0              0             0          3
# 3084       0   33             0              0             1          1
# ...      ...  ...           ...            ...           ...        ...
# 3364       0   42             0              0             1          0
# 2450       1   79             0              0             1          2
# 2903       0   43             0              0             1          1
# 291        1   13             0              0             0          3
# 1966       0   73             0              0             1          2
#
#       Residence_type  avg_glucose_level   bmi  smoking_status
# ...

# %%
y_train.value_counts()
# Out:
# stroke
# 0    3372
# 1     131
# Name: count, dtype: int64

# %%
# Initialize SMOTE
smote = SMOTE(random_state=42)

# Fit and transform the training data
X_resampled, y_resampled = smote.fit_resample(x_train, y_train)
# Fit and transform the testing data
X_resampled_test, y_resampled_test = smote.fit_resample(x_test, y_test)

# %%
y_test.value_counts()
# Out:
# stroke
# 0    842
# 1     34
# Name: count, dtype: int64

# %%
y_resampled_test.value_counts()
# Out:
# stroke
# 0    842
# 1    842
# Name: count, dtype: int64

# %%
scalar=StandardScaler()

# %%
xtrain_sc=scalar.fit_transform(X_resampled)
xtrain_sc
# Out:
# array([[-0.6620119 ,  0.41278976, -0.24605713, ..., -0.06387976,
#          1.8957472 , -0.22577858],
#        [-0.6620119 ,  0.27928865, -0.24605713, ..., -0.50274631,
#          0.5002957 ,  1.7829955 ],
#        [ 1.51054686,  0.41278976, -0.24605713, ..., -0.62980863,
#          0.37506287, -1.23016562],
#        ...,
#        [-0.6620119 , -0.07671431, -0.24605713, ..., -0.10115121,
#         -0.20256352,  0.77860846],
#        [ 1.51054686,  0.41278976, -0.24605713, ..., -0.76983942,
#          0.05734453, -1.23016562],
#        [-0.6620119 ,  0.63529162, -0.24605713, ...,  0.265568  ,
#         -0.1327227 ,  0.77860846]])

# %%
X_train=pd.DataFrame(xtrain_sc,columns=x.columns)
X_train
# Out:
#         gender       age  hypertension  heart_disease  ever_married  \
# 0    -0.662012  0.412790     -0.246057      -0.158366      0.691357
# 1    -0.662012  0.279289     -0.246057      -0.158366      0.691357
# 2     1.510547  0.412790     -0.246057      -0.158366      0.691357
# 3    -0.662012 -0.744220     -0.246057      -0.158366      0.691357
# 4     1.510547 -1.055722     -0.246057      -0.158366      0.691357
# ...        ...       ...           ...            ...           ...
# 6739  1.510547  0.590791     -0.246057      -0.158366      0.691357
# 6740 -0.662012  1.035795     -0.246057      -0.158366     -1.446430
# 6741 -0.662012 -0.076714     -0.246057      -0.158366      0.691357
# 6742  1.510547  0.412790     -0.246057      -0.158366      0.691357
# 6743 -0.662012  0.635292     -0.246057      -0.158366      0.691357
#
#       work_type  Residence_type  avg_glucose_level       bmi  smoking_status
# ...

# %%
x_test_sc=scalar.transform(X_resampled_test)
X_test=pd.DataFrame(x_test_sc,columns=x.columns)
X_test
# Out:
#         gender       age  hypertension  heart_disease  ever_married  \
# 0     1.510547  0.190288      4.064097      -0.158366      0.691357
# 1    -0.662012 -1.812229     -0.246057      -0.158366     -1.446430
# 2    -0.662012 -1.189224     -0.246057      -0.158366     -1.446430
# 3    -0.662012 -2.301733     -0.246057      -0.158366     -1.446430
# 4    -0.662012 -0.922221     -0.246057      -0.158366      0.691357
# ...        ...       ...           ...            ...           ...
# 1679 -0.662012 -0.432717     -0.246057      -0.158366      0.691357
# 1680 -0.662012  0.635292     -0.246057      -0.158366      0.691357
# 1681 -0.662012  0.857793     -0.246057      -0.158366      0.691357
# 1682 -0.662012 -0.833221     -0.246057      -0.158366      0.691357
# 1683 -0.662012  1.169296     -0.246057      -0.158366      0.691357
#
#       work_type  Residence_type  avg_glucose_level       bmi  smoking_status
# ...

# %% [markdown]
# # Model Building

# %%
models={'LG':LogisticRegression(),
        'DT':DecisionTreeClassifier(criterion='gini',random_state=3,max_depth=5),
        'knn' :KNeighborsClassifier(n_neighbors=5),
        'RF':RandomForestClassifier(),
        'BF':BalancedRandomForestClassifier(),
        'svm':SVC(),
        'GBC':GradientBoostingClassifier()
       }
def model_selection(models,x_train,y_resampled,x_test,y_test):
    for name,model in models.items():
        model.fit(x_train,y_resampled)
        y_pred=model.predict(x_test)
        test_accuracy=accuracy_score(y_resampled_test,y_pred)
        print(f'Accurcay using {name} =',test_accuracy)
        print('=====================================================')
        report=classification_report(y_resampled_test,y_pred)
        print(f'Report',report)
        print('=====================================================')

# %%
# models={'BF':BalancedRandomForestClassifier()
#        }
# def model_selection(models,x_train,y_train,x_test,y_test):
#     for name,model in models.items():
#         model.fit(x_train,y_train)
#         y_pred=model.predict(x_test)
#         test_accuracy=accuracy_score(y_test,y_pred)
#         print(f'Accurcay using {name} =',test_accuracy)
#         print('=====================================================')
#         report=classification_report(y_test,y_pred)
#         print(f'Report',report)
#         print('=====================================================')

# %%
model_selection(models,X_train,y_resampled,X_test,y_resampled_test)
# Out:
# Accurcay using LG = 0.767814726840855
# ...
# Report               precision    recall  f1-score   support
#
#            0       0.75      0.81      0.78       842
#            1       0.79      0.73      0.76       842
#
#     accuracy                           0.77      1684
#    macro avg       0.77      0.77      0.77      1684
# weighted avg       0.77      0.77      0.77      1684
#
# ...
# Accurcay using DT = 0.7416864608076009
# ...
# Report               precision    recall  f1-score   support
#
#            0       0.76      0.71      0.73       842
#            1       0.73      0.78      0.75       842
#
#     accuracy                           0.74      1684
#    macro avg       0.74      0.74      0.74      1684
# weighted avg       0.74      0.74      0.74      1684
#
# ...
# Accurcay using knn = 0.7286223277909739
# ...
# Report               precision    recall  f1-score   support
#
#            0       0.69      0.85      0.76       842
#            1       0.80      0.61      0.69       842
#
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

param_grid = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

# %%
grid_search = GridSearchCV(GradientBoostingClassifier(), param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train,y_resampled)
print(grid_search.best_params_)
# Out:
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}

# %%
best_params={'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}

# %%
# Train the final model
final_model = GradientBoostingClassifier(**best_params)
final_model.fit(X_train, y_resampled)
# Out:
# GradientBoostingClassifier(max_depth=5, min_samples_leaf=2, n_estimators=200)

# %%
pred=final_model.predict(X_test)
pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
test_accuracy=accuracy_score(y_resampled_test,pred)
print(f'Accurcay using  =',test_accuracy)
print('=====================================================')
report=classification_report(y_resampled_test,pred)
print(f'Report',report)
print('=====================================================')
# Out:
# Accurcay using  = 0.7713776722090261
# ...
# Report               precision    recall  f1-score   support
#
#            0       0.70      0.95      0.81       842
#            1       0.92      0.60      0.72       842
#
#     accuracy                           0.77      1684
#    macro avg       0.81      0.77      0.76      1684
# weighted avg       0.81      0.77      0.76      1684
#
# ...

# %%
from scipy.stats import uniform, randint

param_dist = {
    'n_estimators': randint(50, 300),
    'learning_rate': uniform(0.01, 0.2),
    'max_depth': randint(3, 10),
    'min_samples_split': randint(2, 10),
    'min_samples_leaf': randint(1, 10)
}

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import GradientBoostingClassifier

model = GradientBoostingClassifier()
random_search = RandomizedSearchCV(model, param_distributions=param_dist, n_iter=100, cv=5, scoring='accuracy', random_state=42, n_jobs=-1)

# %%
random_search.fit(X_train, y_resampled)
# Out:
# RandomizedSearchCV(cv=5, estimator=GradientBoostingClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000250B0E6DF40>,
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000250A9E78740>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000250AC1F4D10>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000250AC1C0110>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000250AC436420>},
#                    random_state=42, scoring='accuracy')

# %%
best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test)
accuracy = accuracy_score(y_resampled_test, y_pred)
print(f'Best Parameters: {random_search.best_params_}')
print(f'Accuracy: {accuracy}')
print(classification_report(y_resampled_test, y_pred))
# Out:
# Best Parameters: {'learning_rate': np.float64(0.19437484700462337), 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5, 'n_estimators': 298}
# Accuracy: 0.6870546318289786
#               precision    recall  f1-score   support
#
#            0       0.62      0.96      0.75       842
#            1       0.92      0.41      0.57       842
#
#     accuracy                           0.69      1684
#    macro avg       0.77      0.69      0.66      1684
# weighted avg       0.77      0.69      0.66      1684

# %%
df
# Out:
#       gender  age  hypertension  heart_disease ever_married work_type  \
# 0       Male   80             0              1          Yes   Private
# 1       Male   74             1              1          Yes   Private
# 2     Female   69             0              0           No   Private
# 3     Female   78             0              0          Yes   Private
# 4     Female   81             1              0          Yes   Private
# ...      ...  ...           ...            ...          ...       ...
# 4374    Male   58             0              0          Yes  Govt_job
# 4375    Male   41             0              0           No   Private
# 4376  Female   45             1              0          Yes  Govt_job
# 4377    Male   40             0              0          Yes   Private
# 4378  Female   80             1              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# ...

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
GBC=GradientBoostingClassifier()
GBC.fit(X_train,y_resampled)
# Out:
# GradientBoostingClassifier()

# %%
import pickle
# Saving model,scaler,encoder
pickle.dump(GBC,open('final_Model.pkl','wb'))
pickle.dump(scalar,open('final_Scaler.pkl','wb'))
pickle.dump(lb,open('label_encoder.pkl','wb'))

# %%
# Loading 
model = pickle.load(open('final_Model.pkl','rb'))
scalar=pickle.load(open('final_scaler.pkl','rb'))
lb=pickle.load(open('label_encoder.pkl','rb'))

# %%
def data_preprocessing(data,lb,scaler,model):
    data1=pd.DataFrame(data,columns=['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
       'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
       'smoking_status'])
    categorical=data1.select_dtypes(include='object').columns
    for cat in categorical:
        data1[cat]=lb.fit_transform(data1[cat])
    scaled_data=scaler.fit_transform(data1)
    model = pickle.load(open('final_Model.pkl','rb'))
    new_data=pd.DataFrame(scaled_data,columns=data1.columns)
    prediction=model.predict(new_data)
    print(prediction)

# %%
sample=[['Female',78,0,0,'Yes','Private','Urban',58.57,24.2,'Unknown']]
sample1=[['Male',41,0,0,'No','Private','Rural',70.15,29.8,'formerly smoked']]
sample2=[['Male',40,0,0,'Yes','Private','Rural',83.94,30.0,'smokes']]

# %%
data1=pd.DataFrame(sample1,columns=['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
       'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
       'smoking_status'])
data1
# categorical=data.select_dtypes(include='object').columns
#     for cat in categorical:
#         data[cat]=lb.fit_transform(data[cat])
# Out:
#   gender  age  hypertension  heart_disease ever_married work_type  \
# 0   Male   41             0              0           No   Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status
# 0          Rural              70.15  29.8  formerly smoked

# %%
# LR=LogisticRegression()
lb=LabelEncoder()
scalar=StandardScaler()
data_preprocessing(sample,lb,scalar,GBC)
# Out:
# [1]

# %%
# LR=LogisticRegression()
lb=LabelEncoder()
scalar=StandardScaler()
data_preprocessing(sample1,lb,scalar,GBC)
# Out:
# [1]

# %%
# LR=LogisticRegression()
lb=LabelEncoder()
scalar=StandardScaler()
data_preprocessing(sample2,lb,scalar,GBC)
# Out:
# [1]
